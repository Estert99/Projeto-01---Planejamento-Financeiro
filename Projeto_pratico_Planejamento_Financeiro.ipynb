# %% [markdown]
# <a href="https://colab.research.google.com/github/Estert99/Projeto-01---Planejamento-Financeiro/blob/main/Projeto_pratico_Planejamento_Financeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Criei uma uma planilha do Execel com os dados Despesas mensais.
# Importei a os dados fiz o pre processamento.
#
# A planilha foi exportada com valores nulos e linha em branco.
# No codigo abaixo eu:
# Importei a os dados fiz o pre processamento.
# Identifiquei o tipo de dados.
# Renomei as colunas
# Removi os valores nulos.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("/Projeto.xlsx")

print(df.head()) #imprime as 5  primeiras linhas da tabela

print(df.info()) #iprime o nome da coluna e os tipos de dados

print(df.describe()) #imprime o resumo estatistico

print(df.isnull().sum()) #checa  os valores nulos

print(df["Categoria"].unique()) #imprime as categorias unicas

print(df["Tipo"].value_counts()) #imprime quantos regristo de cada tipo

df= df.dropna(subset = ['Data','Valor ']) #elima os valores nulos
df.columns = df.columns.str.replace(' ', '_') #renomei a coluna Valor
df['Tipo']= df.Tipo.replace('Saida',"Saída") #renomei os dados da coluna Tipo
# Out:
#         Data         Descrição    Categoria  Valor      Tipo
# 0        NaT               NaN          NaN     NaN      NaN
# 1 2026-06-05           Salario        Renda  1090.0  Entrada
# 2 2026-06-05  Vale Alimentação  Alimentação   200.0  Entrada
# 3 2026-06-07            Alugel      Moradia   700.0    Saida
# 4 2026-06-09      Passe mensal   Transporte    30.0    Saida
# [nan 'Renda' 'Alimentação' 'Moradia' 'Transporte' 'Telefone' 'Compras'
#  'TOTAL' 'TOTAL EM SAIDAS' 'TOTAL PARA POUPAR']
